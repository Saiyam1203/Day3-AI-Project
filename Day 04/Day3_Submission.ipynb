# %%
import numpy as np

data_points = np.array([10, 20, 30, 40])

matrix = data_points.reshape(2, 2)
print("Matrix:\n", matrix)

processed_data = data_points * 2
print("Scaled Data:", processed_data)
# Out:
# Matrix:
#  [[10 20]
#  [30 40]]
# Scaled Data: [20 40 60 80]

# %%
import pandas as pd

df = pd.read_csv("data.csv")

print(df.head())
print(df.describe())
print("Average Score:", df['Score'].mean())
# Out:
#       Name  Age  Score
# 0    Alice   21     80
# 1      Bob   22     75
# 2  Charlie   23     90
#         Age      Score
# count   3.0   3.000000
# mean   22.0  81.666667
# std     1.0   7.637626
# min    21.0  75.000000
# 25%    21.5  77.500000
# 50%    22.0  80.000000
# 75%    22.5  85.000000
# max    23.0  90.000000
# Average Score: 81.66666666666667

# %%
### Vectorization

Vectorization means performing operations on entire datasets at once instead of using loops. It improves speed and efficiency, which is very important in AI.
